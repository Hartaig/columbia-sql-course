# %%
import pandas as pd
import numpy as np
import mysql.connector
import os

# %env MYSQL_PASSWORD=<your_password> # enter mysql password here to save in environment

conn = mysql.connector.connect(
    host="localhost",
    user="root",              # your MySQL username
    password=os.getenv("MYSQL_PASSWORD"), # password previously saved in environment
    database="myclassdb"      # the DB you created in Workbench
)

cursor = conn.cursor()

cursor.execute("SELECT * FROM citibike LIMIT 1000;")
data = cursor.fetchall()
columns = [col[0] for col in cursor.description]

df = pd.DataFrame(data, columns=columns)
df
# Out:
#               ride_id  rideable_type          started_at            ended_at  \
# 0    AABD1C039D2D622D  electric_bike 2025-08-18 09:02:16 2025-08-18 09:07:46
# 1    3420D743AD40EDC8   classic_bike 2025-08-15 14:04:19 2025-08-15 14:29:45
# 2    6957013BE2AF6B52   classic_bike 2025-08-23 13:56:08 2025-08-23 13:59:59
# 3    B005E728E67ED43F  electric_bike 2025-08-19 17:41:54 2025-08-19 17:50:22
# 4    2BF0B8E6F05BC2AF   classic_bike 2025-08-27 09:26:19 2025-08-27 09:31:24
# ..                ...            ...                 ...                 ...
# 995  61175B005A07B958   classic_bike 2025-08-04 00:00:57 2025-08-04 00:05:53
# 996  77FEA27169306F46   classic_bike 2025-08-19 15:15:54 2025-08-19 15:23:42
# 997  BB2612FCED6F5FEF  electric_bike 2025-08-06 18:07:00 2025-08-06 18:13:47
# 998  4F00AF1D26CD5E6E   classic_bike 2025-08-18 19:53:32 2025-08-18 19:55:59
# 999  6D6545DC5768AAE3   classic_bike 2025-08-19 20:19:14 2025-08-19 20:24:42
#
# ...
